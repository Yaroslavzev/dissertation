# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion
# Out:
# <function matplotlib.pyplot.ion>

# %%
fig = plt.figure()

ax = fig.add_subplot(111)

ax.set_xlim(-20,200)
ax.set_ylim(273,1250)

A = 0, 22, 32, 72, 92, 142, 162, 182
B = 273, 390, 390, 1080, 1080, 500, 500, 273

plt.plot(A,B, linewidth=3.0)


a1 = -20,22
b1 = 390,390

a2 = -20,72
b2 = 1080,1080

a3 = -20,142
b3 = 500,500


plt.text(-10, 400,r'T$\approx390$', size = 15)
plt.text(-10, 1100,r'T$\approx1080$', size = 15)
plt.text(-10, 520,r'T$\approx500$', size = 15)

plt.plot(a1, b1, 'r--',a2, b2, 'r--',a3, b3, 'r--', linewidth=3.0)


plt.xlabel(u'Время, ч', fontsize=16)
plt.ylabel(u'Температура, К', fontsize=16)
plt.grid(True)

plt.rc('axes', linewidth=3) 
plt.tick_params(axis='both', labelsize = 15)

plt.tight_layout()
plt.savefig('synthesis.png', dpi = 600)

plt.show()
